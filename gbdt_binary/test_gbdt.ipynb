# %%
# !python gfederated.py
# Out:
# node id:1, threshold:0.9
# node id:2, threshold:0.9
# node id:3, threshold:0.9
# node id:4, threshold:0.9
# node id:5, threshold:0.9
# node id:6, threshold:0.9
# node id:7, threshold:0.9
# node id:8, threshold:0.9
# node id:9, threshold:0.9
# node id:10, threshold:0.9
# node id:11, threshold:0.9
# node id:12, threshold:0.9
# node id:13, threshold:0.9
# node id:14, threshold:0.9
# node id:15, threshold:0.9
# node id:16, threshold:0.9
# node id:17, threshold:0.9
# node id:18, threshold:0.9
# node id:19, threshold:0.9
# node id:20, threshold:0.9
# node id:21, threshold:0.9
# node id:22, threshold:0.9
# node id:23, threshold:0.9
# node id:24, threshold:0.9
# node id:25, threshold:0.9
# node id:26, threshold:0.9
# node id:27, threshold:0.9
# node id:28, threshold:0.9
# node id:29, threshold:0.9
# node id:30, threshold:0.9
# node id:31, threshold:0.9
# node id:32, threshold:0.9
# node id:33, threshold:0.9
# node id:34, threshold:0.9
# node id:35, threshold:0.9
# node id:36, threshold:0.9
# ...
