# %%
# !python gfederated.py
# Out:
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# (159, 16)
# (299, 17)
# ...
